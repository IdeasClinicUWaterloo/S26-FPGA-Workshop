# %% [markdown]
# # SystemVerilog Guide

# %% [markdown]
# This is a brief guide covering the SystemVerilog syntax needed for this workshop.

# %% [markdown]
# ### Table of Contents
# 1. [Types of Blocks](1_blocks.ipynb)
# 2. [Assignment Operators](2_operators.ipynb)
# 3. [Variables and Arrays](3_variables_arrays.ipynb)
# 4. [If-Else Statement](4_if_else.ipynb)
# 5. [Modules](5_modules.ipynb)

# %% [markdown]
# ---

# %% [markdown]
# <div style="display:flex; justify-content:space-between;">
#   <span></span>
#   <span><b>Next: </b> <a href="1_blocks.ipynb">Types of Blocks</a></span>
# </div>
