# %% [markdown]
# ## 1. Types of Blocks
#
# SystemVerilog has different types of blocks depending on the kind of logic you are writing.
#
# ### Continuous (`assign`)
# - Updates immediately when inputs change
# - Used for: one-line expressions, simple wiring
#
# Example:
# ```systemverilog
# assign y = a + b;
# ```
#
# ### Sequential (`always_ff`)
# - Updates are triggered on a clock edge
# - Used for: when you have a clock, when you have memory
#
# Example:
# ```systemverilog
# always_ff @(posedge clk or posedge reset) begin
#     if (reset) begin
#         y <= 0;
#     end
#     else begin
#         y <= a + b;
#     end
# end
# ```

# %% [markdown]
# ---

# %% [markdown]
# <div style="display:flex; justify-content:center; position:relative;">
#   <span style="position:absolute; left:0;">
#     <b>Back:</b> <a href="table_contents.ipynb">Table of Contents</a>
#   </span>
#
#   <span>
#     <b><a href="table_contents.ipynb">Top</a></b>
#   </span>
#
#   <span style="position:absolute; right:0;">
#     <b>Next:</b> <a href="2_operators.ipynb">Assignment Operators</a>
#   </span>
# </div>
