# %% [markdown]
# ## 2. Assignment Operators
#
# ### Blocking Assignment (`<=`)
# - Used for writing logic triggered by a clock edge (e.g. `always_ff @(posedge clk)` or `always @(posedge clk)`)
#
# Example:
#
# ```systemverilog
# always_ff @(posedge clk) begin
#     y <= a + b;
# end
# ```
#
# ### Non-Blocking Assignment (`=`)
# - Used for writing logic that reacts to input changes (e.g. `always_comb`)
#
# ```systemverilog
# always_comb begin
#     y <= a + b;
# end
# ```

# %% [markdown]
# ---

# %% [markdown]
# <div style="display:flex; justify-content:center; position:relative;">
#   <span style="position:absolute; left:0;">
#     <b>Back:</b> <a href="1_blocks.ipynb">Types of Blocks</a>
#   </span>
#
#   <span>
#     <b><a href="table_contents.ipynb">Top</a></b>
#   </span>
#
#   <span style="position:absolute; right:0;">
#     <b>Next:</b> <a href="3_variables_arrays.ipynb">Variables and Arrays</a>
#   </span>
# </div>
