# %% [markdown]
# ## 4. If-Else Statement
#
# Used inside `always_ff` blocks.
#
# General Syntax:
# ```systemverilog
# if (<condition>) begin
#     // statement 1
# end
# else begin
#     // statement 2
# end
# ```
# Example:
# ```systemverilog
# if (a == 1) begin
#     result <= a + b;
# end
# else if (a == 2) begin
#     result <= a - b;
# end
# else begin
#     result <= a * b;
# end
# ```

# %% [markdown]
# ---

# %% [markdown]
# <div style="display:flex; justify-content:space-between;">
#   <span><b>Back: </b> <a href="3_variables_arrays.ipynb">Variables and Arrays</a></span>
#   <span><b>Next: </b> <a href="5_modules.ipynb">Modules</a></span>
# </div>
